# %% [markdown]
# # Lesson 1.1: Lists, Dicts, Tuples
#
# In Laravel, you use arrays for everything. Python has **3 main types**:
# - **Lists** → Like PHP indexed arrays (mutable, ordered)
# - **Dicts** → Like PHP associative arrays (key-value pairs)
# - **Tuples** → Like arrays but IMMUTABLE (can't change after creation)

# %% [markdown]
# ## LISTS - Like PHP indexed arrays

# %%
# PHP:  $users = ['Alice', 'Bob', 'Charlie'];
# Create same list in Python and show how to access elements (similar to PHP but with some differences)

users = ['Alice', 'Bob', 'Charlie', 'David', 'Eve']

print(users[0])  # Accessing the first element (Alice)
print(users[-1]) # Accessing the last element (Eve)
print(users[0:2]) # Accessing a slice of the list (Alice and Bob) 0 represents the starting index and 2 represents the ending index (exclusive)
print(users[1:])  # Accessing all elements from index 1 to the end (Bob, Charlie, David, Eve)
print(users[:3])  # Accessing all elements from the beginning to index 3 ( Alice, Bob, Charlie)

for user in users:
    if user == 'Charlie':
        print("Found Charlie!")  # Checking for a specific user and printing a message if found
    elif user == 'Eve':
        print("Found Eve!")  # Checking for another specific user and printing a message if found
    else:
        print(f"User: {user}")  # Printing the name of each user in the list

print(len(users))  # Getting the number of users in the list
print(users.index('David'))  # Finding the index of a specific user (David)
print('Alice' in users)  # Checking if a specific user (Alice) is in the list
print(type(users))  # Checking the type of the users variable (should be <class 'list'>)
users.append('Frank')  # Adding a new user to the end of the list
print(users)  # Printing the updated list of users
users.remove('Bob')  # Removing a specific user (Bob) from the list
print(users)  # Printing the updated list of users after removal
users.sort(reverse=True)  # Sorting the list of users in reverse alphabetical order
print(users)  # Printing the sorted list of users
# Out:
# Alice
# Eve
# ['Alice', 'Bob']
# ['Bob', 'Charlie', 'David', 'Eve']
# ['Alice', 'Bob', 'Charlie']
# User: Alice
# User: Bob
# Found Charlie!
# User: David
# Found Eve!
# 5
# 3
# True
# <class 'list'>
# ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank']
# ['Alice', 'Charlie', 'David', 'Eve', 'Frank']
# ['Frank', 'Eve', 'David', 'Charlie', 'Alice']

# %%
# Adding elements
# PHP:  $users[] = 'David';  OR  array_push($users, 'David');
users.append('David')
print(users)           # ['Alice', 'Bob', 'Charlie', 'David']
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']

# %%
# Slicing (PHP: array_slice)
# Python slicing is POWERFUL - syntax: list[start:end:step]
print(users[1:3])      # ['Bob', 'Charlie'] - items at index 1 and 2
print(users[:2])       # ['Alice', 'Bob'] - first 2 items
print(users[2:])       # ['Charlie', 'David'] - from index 2 to end

# Length
# PHP:  count($users)
print(len(users))      # 4

# %% [markdown]
# ## DICTS - Like PHP associative arrays

# %%
# PHP:  $user = ['name' => 'Alice', 'age' => 30, 'role' => 'admin'];
# Python:
user = {'name': 'Alice', 'age': 30, 'role': 'admin'}

# Accessing values
# PHP:  $user['name']
print(user['name'])    # Alice

# Safe access (like $user['email'] ?? 'default' in PHP)
# PHP:  $user['email'] ?? 'no email'
print(user.get('email', 'no email'))  # no email
# Out:
# Alice
# no email

# %%
# Adding/updating
user['email'] = 'alice@example.com'
user['age'] = 31       # Update existing

# Looping through dict
# PHP:  foreach($user as $key => $value)
for key, value in user.items():
    print(f"{key}: {value}")
# Out:
# name: Alice
# age: 31
# role: admin
# email: alice@example.com

# %%
# Get all keys or values
print(user.keys())     # dict_keys(['name', 'age', 'role', 'email'])
print(user.values())   # dict_values(['Alice', 31, 'admin', 'alice@example.com'])
# Out:
# dict_keys(['name', 'age', 'role', 'email'])
# dict_values(['Alice', 31, 'admin', 'alice@example.com'])

# %% [markdown]
# ## TUPLES - Immutable lists (PHP has no equivalent)
#
# Use tuples when data shouldn't change (coordinates, RGB colors, etc.)
#
# Why use tuples?
# 1. Safer - prevents accidental modification
# 2. Faster - Python optimizes immutable data
# 3. Can be used as dict keys (lists can't)

# %%
coordinates = (10, 20)
rgb_red = (255, 0, 0)

# Access like lists
print(coordinates[0])  # 10

# But you CAN'T modify them:
# coordinates[0] = 15  # This would raise an ERROR!

# Tuple unpacking - very Pythonic!
x, y = coordinates
print(f"x={x}, y={y}")  # x=10, y=20

# %%
# This is how functions return multiple values in Python:
def get_user_info():
    return 'Alice', 30, 'admin'  # Returns a tuple

name, age, role = get_user_info()
print(f"{name} is {age} years old")

# %% [markdown]
# ## Quick Comparison
#
# | Feature          | PHP                    | Python               |
# |------------------|------------------------|----------------------|
# | Indexed array    | `$arr = [1, 2, 3]`    | `arr = [1, 2, 3]`   |
# | Assoc array      | `$arr = ['a' => 1]`   | `arr = {'a': 1}`    |
# | Access           | `$arr[0]`              | `arr[0]`             |
# | Add to list      | `$arr[] = 4`           | `arr.append(4)`      |
# | Length           | `count($arr)`          | `len(arr)`           |
# | Check key exists | `isset($arr['key'])`   | `'key' in arr`       |
# | Last element     | `end($arr)`            | `arr[-1]`            |

# %% [markdown]
# ## Exercise: Try these yourself!
#
# 1. Create a list of 5 programming languages you know
# 2. Create a dict representing a Laravel project (name, version, packages)
# 3. Use tuple unpacking to swap two variables: `a, b = b, a`

# %%
# YOUR CODE HERE
# languages = [...]
# laravel_project = {...}
# a, b = 5, 10
# a, b = ...  # Swap them
# print(f"After swap: a={a}, b={b}")
